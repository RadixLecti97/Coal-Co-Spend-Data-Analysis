# %%
import pandas as pd
import numpy as np

data = pd.read_csv('coal co duplicates.csv')

#fix column headers to = the first row's values
data.columns = data.iloc[0]
df = pd.DataFrame(data)
df.head()
# Out:
# 0   3593.75  DME  PA COAL ALLIANCE  (blank)   Q3  2015.0    Exempt  \
# 0   3593.75  DME  PA COAL ALLIANCE  (blank)   Q3  2015.0    Exempt
# 1  95134.06  DME          Barclays  (blank)   Q1  2015.0  Indirect
# 2   1757.46  DME          Barclays  (blank)   Q1  2015.0  Indirect
# 3  72619.87  DME          Barclays  (blank)   Q1  2015.0  Indirect
# 4   5833.34  DME          Barclays  (blank)   Q1  2015.0  Indirect
#
# 0                  Business Related             Licenses & Permits  \
# 0                  Business Related             Licenses & Permits
# 1  Financial and Insurance Services  Banking & Investment Services
# 2  Financial and Insurance Services  Banking & Investment Services
# 3  Financial and Insurance Services  Banking & Investment Services
# 4  Financial and Insurance Services  Banking & Investment Services
#
# 0                         NaN
# 0                         NaN
# 1  Banking Services - General
# 2  Banking Services - General
# 3  Banking Services - General
# ...

# %%
df.columns = ['index','Branch','Vendor','blank','Quarter','Year','Type','Industry 1','Industry 2','Industry 3']
df.head()
# Out:
#       index Branch            Vendor    blank Quarter    Year      Type  \
# 0   3593.75    DME  PA COAL ALLIANCE  (blank)      Q3  2015.0    Exempt
# 1  95134.06    DME          Barclays  (blank)      Q1  2015.0  Indirect
# 2   1757.46    DME          Barclays  (blank)      Q1  2015.0  Indirect
# 3  72619.87    DME          Barclays  (blank)      Q1  2015.0  Indirect
# 4   5833.34    DME          Barclays  (blank)      Q1  2015.0  Indirect
#
#                          Industry 1                     Industry 2  \
# 0                  Business Related             Licenses & Permits
# 1  Financial and Insurance Services  Banking & Investment Services
# 2  Financial and Insurance Services  Banking & Investment Services
# 3  Financial and Insurance Services  Banking & Investment Services
# 4  Financial and Insurance Services  Banking & Investment Services
#
#                    Industry 3
# 0                         NaN
# 1  Banking Services - General
# 2  Banking Services - General
# ...

# %%
df.head()
# Out:
#       index Branch            Vendor    blank Quarter    Year      Type  \
# 0   3593.75    DME  PA COAL ALLIANCE  (blank)      Q3  2015.0    Exempt
# 1  95134.06    DME          Barclays  (blank)      Q1  2015.0  Indirect
# 2   1757.46    DME          Barclays  (blank)      Q1  2015.0  Indirect
# 3  72619.87    DME          Barclays  (blank)      Q1  2015.0  Indirect
# 4   5833.34    DME          Barclays  (blank)      Q1  2015.0  Indirect
#
#                          Industry 1                     Industry 2  \
# 0                  Business Related             Licenses & Permits
# 1  Financial and Insurance Services  Banking & Investment Services
# 2  Financial and Insurance Services  Banking & Investment Services
# 3  Financial and Insurance Services  Banking & Investment Services
# 4  Financial and Insurance Services  Banking & Investment Services
#
#                    Industry 3
# 0                         NaN
# 1  Banking Services - General
# 2  Banking Services - General
# ...

# %%
df.drop(columns=['blank'])
# Out:
#            index Branch                                       Vendor Quarter  \
# 0        3593.75    DME                             PA COAL ALLIANCE      Q3
# 1       95134.06    DME                                     Barclays      Q1
# 2        1757.46    DME                                     Barclays      Q1
# 3       72619.87    DME                                     Barclays      Q1
# 4        5833.34    DME                                     Barclays      Q1
# 5       34880.04    DME                                     Barclays      Q1
# 6        2752.42    DME                                     Barclays      Q1
# 7       67751.00    DME                                     Barclays      Q1
# 8        8612.84    DME                                     Barclays      Q1
# 9       52554.25    DME                                     Barclays      Q1
# 10       8124.13    DME                                     Barclays      Q1
# ...

# %%
df['Years']=round(df['Year'] )

# %%
df.head()
# Out:
#       index Branch            Vendor    blank Quarter    Year      Type  \
# 0   3593.75    DME  PA COAL ALLIANCE  (blank)      Q3  2015.0    Exempt
# 1  95134.06    DME          Barclays  (blank)      Q1  2015.0  Indirect
# 2   1757.46    DME          Barclays  (blank)      Q1  2015.0  Indirect
# 3  72619.87    DME          Barclays  (blank)      Q1  2015.0  Indirect
# 4   5833.34    DME          Barclays  (blank)      Q1  2015.0  Indirect
#
#                          Industry 1                     Industry 2  \
# 0                  Business Related             Licenses & Permits
# 1  Financial and Insurance Services  Banking & Investment Services
# 2  Financial and Insurance Services  Banking & Investment Services
# 3  Financial and Insurance Services  Banking & Investment Services
# 4  Financial and Insurance Services  Banking & Investment Services
#
#                    Industry 3   Years
# 0                         NaN  2015.0
# 1  Banking Services - General  2015.0
# ...

# %%
df=df[['index','Branch','Vendor','blank','Quarter','Year','Years','Type','Industry 1','Industry 2','Industry 3']]
df.head()
# Out:
#       index Branch            Vendor    blank Quarter    Year   Years  \
# 0   3593.75    DME  PA COAL ALLIANCE  (blank)      Q3  2015.0  2015.0
# 1  95134.06    DME          Barclays  (blank)      Q1  2015.0  2015.0
# 2   1757.46    DME          Barclays  (blank)      Q1  2015.0  2015.0
# 3  72619.87    DME          Barclays  (blank)      Q1  2015.0  2015.0
# 4   5833.34    DME          Barclays  (blank)      Q1  2015.0  2015.0
#
#        Type                        Industry 1                     Industry 2  \
# 0    Exempt                  Business Related             Licenses & Permits
# 1  Indirect  Financial and Insurance Services  Banking & Investment Services
# 2  Indirect  Financial and Insurance Services  Banking & Investment Services
# 3  Indirect  Financial and Insurance Services  Banking & Investment Services
# 4  Indirect  Financial and Insurance Services  Banking & Investment Services
#
#                    Industry 3
# 0                         NaN
# ...

# %%
df.drop('blank',1)
# Out:
#            index Branch                                       Vendor Quarter  \
# 0        3593.75    DME                             PA COAL ALLIANCE      Q3
# 1       95134.06    DME                                     Barclays      Q1
# 2        1757.46    DME                                     Barclays      Q1
# 3       72619.87    DME                                     Barclays      Q1
# 4        5833.34    DME                                     Barclays      Q1
# 5       34880.04    DME                                     Barclays      Q1
# 6        2752.42    DME                                     Barclays      Q1
# 7       67751.00    DME                                     Barclays      Q1
# 8        8612.84    DME                                     Barclays      Q1
# 9       52554.25    DME                                     Barclays      Q1
# 10       8124.13    DME                                     Barclays      Q1
# ...

# %%
df.head()
# Out:
#       index Branch            Vendor Quarter    Year   Years      Type  \
# 0   3593.75    DME  PA COAL ALLIANCE      Q3  2015.0  2015.0    Exempt
# 1  95134.06    DME          Barclays      Q1  2015.0  2015.0  Indirect
# 2   1757.46    DME          Barclays      Q1  2015.0  2015.0  Indirect
# 3  72619.87    DME          Barclays      Q1  2015.0  2015.0  Indirect
# 4   5833.34    DME          Barclays      Q1  2015.0  2015.0  Indirect
#
#                          Industry 1                     Industry 2  \
# 0                  Business Related             Licenses & Permits
# 1  Financial and Insurance Services  Banking & Investment Services
# 2  Financial and Insurance Services  Banking & Investment Services
# 3  Financial and Insurance Services  Banking & Investment Services
# 4  Financial and Insurance Services  Banking & Investment Services
#
#                    Industry 3
# 0                         NaN
# 1  Banking Services - General
# 2  Banking Services - General
# ...

# %%
df['Years']= round(df['Year'])

# %%
df.head()
# Out:
#       index Branch            Vendor Quarter    Year   Years      Type  \
# 0   3593.75    DME  PA COAL ALLIANCE      Q3  2015.0  2015.0    Exempt
# 1  95134.06    DME          Barclays      Q1  2015.0  2015.0  Indirect
# 2   1757.46    DME          Barclays      Q1  2015.0  2015.0  Indirect
# 3  72619.87    DME          Barclays      Q1  2015.0  2015.0  Indirect
# 4   5833.34    DME          Barclays      Q1  2015.0  2015.0  Indirect
#
#                          Industry 1                     Industry 2  \
# 0                  Business Related             Licenses & Permits
# 1  Financial and Insurance Services  Banking & Investment Services
# 2  Financial and Insurance Services  Banking & Investment Services
# 3  Financial and Insurance Services  Banking & Investment Services
# 4  Financial and Insurance Services  Banking & Investment Services
#
#                    Industry 3
# 0                         NaN
# 1  Banking Services - General
# 2  Banking Services - General
# ...

# %%
df['Years']=df['Years'].astype(str)

# %%
df_out = df[df.duplicated(subset=['Branch','Vendor'],keep=False)].groupby('Branch')['Vendor','index'].agg({'Vendor':'nunique','index':'sum'}).rename(columns={'Vendor':'Count_dups'})

# %%
df_out.head()
# Out:
#         Count_dups         index
# Branch
# ABO            293  2.837827e+07
# BLH            537  4.281682e+07
# CFE            197  1.558241e+07
# DME            334  1.081347e+08

# %%
df_out.rename(columns={'index':'Ext Amt'})
# Out:
#         Count_dups       Ext Amt
# Branch
# ABO            293  2.837827e+07
# BLH            537  4.281682e+07
# CFE            197  1.558241e+07
# DME            334  1.081347e+08
